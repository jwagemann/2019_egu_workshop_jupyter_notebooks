# %% [markdown]
# # 4 Getting to know the Jupyter environment
# ### JupyterLab, JupyterHub, ...

# %% [markdown]
# <hr>
# <a href="./03_Introduction_Jupyter_widgets.ipynb"><< 3 - Introducing Jupyter widgets</a>&nbsp;<space>&nbsp;<space>&nbsp;<space>&nbsp;<space>&nbsp;<space>&nbsp;<space>&nbsp;<space>&nbsp;<space>&nbsp;<space>&nbsp;<space> <a href="./index.ipynb"> Index >></a>

# %% [markdown]
# ## 1.1. Why Jupyter Notebooks

# %% [markdown]
# ## 1.2. Installation

# %% [markdown]
# <hr>
# &copy; 2019 | Julia Wagemann
# <a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img style="float: right" alt="Creative Commons Lizenzvertrag" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/88x31.png" /></a>
